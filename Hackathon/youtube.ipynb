# %%
# !pip install googleapiclient

# %%
import os
import csv
import googleapiclient.discovery

# YouTube API 키 설정
API_KEY = "AIzaSyA6jfTpidjvxDrRVtSKBI3enm9JJJSqsug"

# YouTube Data API 클라이언트 초기화
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

# 동영상 ID
video_id = "YxFZT32iZdE"

# 댓글 가져오기
# def get_video_comments(youtube, **kwargs):
#     comments = []
#     results = youtube.commentThreads().list(**kwargs).execute()

#     while results:
#         for item in results["items"]:
#             comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
#             comments.append(comment)

#         # 다음 페이지의 댓글 가져오기
#         if 'nextPageToken' in results:
#             kwargs['pageToken'] = results['nextPageToken']
#             results = youtube.commentThreads().list(**kwargs).execute()
#         else:
#             break

#     return comments
def get_video_comments(youtube, **kwargs):
    comments = []
    results = youtube.commentThreads().list(**kwargs).execute()

    while results:
        for item in results["items"]:
            # Extract top-level comment
            top_level_comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            comments.append(top_level_comment)

            # Extract replies to the top-level comment, if any
            if "replies" in item:
                for reply_item in item["replies"]["comments"]:
                    reply_text = reply_item["snippet"]["textDisplay"]
                    comments.append(reply_text)

        # Fetch the next page of comments
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = youtube.commentThreads().list(**kwargs).execute()
        else:
            break

    return comments

# Test the function with some print statements
video_comments = get_video_comments(youtube, part="snippet", videoId=video_id, textFormat="plainText")

# Print the extracted comments for debugging
for comment in video_comments:
    print(comment)



# 댓글을 CSV 파일로 저장
csv_filename = 'youtube_comments.csv'
with open(csv_filename, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Comment"])
    for comment in video_comments:
        writer.writerow([comment])

# 성공 메시지 출력
print(f"모든 댓글이 '{csv_filename}' 파일로 성공적으로 추출되었습니다.")
# Out:
# 말로만 계속 북한이 현재 우리나라 80년대 90년대 비슷하다고 하는데 저거 보니 진짜 와닿네
# 해주출신 정중부같은 무장이 지금 북한엔 필요하다
# 앵간한 무한리필집이 저거보다 퀄리티가 훨좋음 ㅋㅋ
# 앵간한 무한리필집이 저거보다 퀄리티가 훨좋음 ㅋㅋ
# 제발 쿠데타 일어나길
# 저게 보여주기식이면 실제로는..... 끔찍하다...
# 명륜진사갈비를 가도 저거보단 낫겠다
# 한반도 ...북이나 남이나 리더가  막장최고야
# 현대판 동탁. 동탁의 목을 벨 여포는 과연 누구일까?
# 윤석열 스럽네 ..
# 적이지만 개죽음 당하는거 보면 불쌍하다 전장에서 싸우다 죽어야지
# 언제가 될지 모르지만 전장에서 만나자!!
# 웃긴게 지도자라는 인간이 먹을것까지 준비해줘야 먹을수있는거냐?ㅋ
# 고기반찬은 일상인데 저긴 얼마나 특별하면 저걸 자랑이랍시고 홍보하냐 ㅉㅉ 거지새끼들 빨리 쳐망해라
# 사과랑 배 가지런히 쌓아둔거봐라 ㅋㅋ 낭만과 순수함이  잇구나 ㅋㅋㅋㅋㅋ
# 예수님 믿고 천국가세요~
#
# "영접하는 자 곧 그 이름을 믿는 자들에게는 하나님의 자녀가 되는 권세를 주셨으니"
#                                                       (요한복음 1장 12절)
# 저런 훈련 좋아 아주 잘하고 있어
# 인민들개 불쌍타 진짜
# 모든 국민들을 제대로 챙겨야 맞지 이 돼지새끼야.
# 지 때문에 다수의 공수부대요원이 사망했는데 저걸로 떼우려하네.
# 그새 . 끼들이 뭘 쳐먹든 먼상관이냐 돼지 면상 보기도 밥맛 떨어지는데  어지간이들 보도해라. 식자재 올라 구내식당 밥 반찬 품질도 떨어져 밥먹기 힘든데 돼지 면상을 보면 밥 맛이 더없다.
# 이런거 보면서 혀는 끌끌차지만
# 정작 투표는 이런 북한과 중국 공산당을 옹호하는 당을 찍는 대한민국 국민 선동수준ㅋ
# 장담컨대 전쟁나면 핵쏘기도 전에 북한은 초박살난다.
# 고기 남아 돌아서 버리는 남한에서는 이해가 어려운... 불쌍한 북한 국민들 ㅉㅉㅉ
# ...
