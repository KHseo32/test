# %% [markdown]
# ### 복습
# 1. response  데이터를 문자열로 저장
# 2. 문자열로 저장된 데이터를 BeautifulSoup를 이용하여 parsing
# 3. div 중 id가 content인 태그 추출
# 4. 3번에서 추출된 tag에서 div 중 class가 today_section인 태그 추출
# 5. 헤드라인만 추출하여 리스트로 생성

# %%
import requests

import pandas as pd

from bs4 import BeautifulSoup as bs

import pprint

# %%
url = 'https://sports.news.naver.com/index'

response = requests.get(url)

# %%
html_data = response.text

# %%
soup = bs(html_data,'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="스포츠홈 : 네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="스포츠의 모든 것, 네이버 스포츠와 함께 하세요" name="description"/>
# <title>스포츠홈 : 네이버 스포츠</title>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsCss.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsHome.css" rel="stylesheet" type="text/css"/>
# ...

# %%
len(
    soup.find_all('div', attrs={
        'class' : 'today_section'
    })
)
# Out:
# 1

# %%
div_sport = soup.find('div', attrs={
    'class' : 'today_section'
})

div_sport
# Out:
# <div class="today_section type_no_da">
# <h3 class="blind">오늘의 스포츠</h3>
# <ul class="today_list">
# <li class="today_item">
# <a class="link_today" data-not-edited="Y" href="/news?oid=421&amp;aid=0007476817" onclick="clickcr(this, 'rnk*r.list', '421_0007476817', '1', event);" title="불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다">
# <div class="image_area">
# <!-- [D] 썸네일 이미지 alt 값 비워주세요. -->
# <img alt="" height="95" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net?src=%22http%3A%2F%2Fimgnews.naver.net%2Fimage%2F421%2F2024%2F04%2F12%2F0007476817_001_20240412081701441.jpg%22&amp;type=nf160_95&amp;service=sports" width="160"/>
# </div>
# <div class="text_area">
# <strong class="title">불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다</strong>
# <!-- [D] 내용 두줄 말줄임 적용해주세요. -->
# <p class="news">
# 							불법 도박에 빠져 많은 돈을 탕진한 오타니의 전 통역사 미즈하라 잇페이(왼쪽). ⓒ AFP=뉴스1(서울=뉴스1) 권혁준 기자 = 오타니 쇼헤이(30·LA 다..."
# 						</p>
# <div class="information">
# <span>뉴스1</span>
# <span>메이저리그</span>
# ...

# %%
titles = div_sport.find_all('strong')

# %%
titles
# Out:
# [<strong class="title">불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다</strong>,
#  <strong class="title">리버풀 선배의 분노와 조언 "유로파 8강 2차전 2군으로···PL 우승에 올인"</strong>,
#  <strong class="title">'연습 때보다 경기때 더 잘하는 스타일'  2군 타율 0. 417→첫 타석 데뷔 첫 3루타. 꽃감독 예상 적중. "칼을 갈고 있었다"</strong>,
#  <strong class="title">'0. 169 캡틴 살려라' 코치 총동원 야간 특타…'78억 첫해' 얼마나 답답했으면</strong>,
#  <strong class="title">'56홈런' 괴물타자에게 무슨일 있나…개막 10경기 45타석 무홈런-무타점</strong>,
#  <strong class="title">'바이에른의 실패한 영입' 김민재, 이제는 '충격 스왑딜' 가능성까지 등장…"세리에A 정상급 윙어와 바꿀 계획"</strong>]

# %%
_titles = titles[0]

# %%
_titles
# Out:
# <strong class="title">불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다</strong>

# %%
titles_list = []

for tag in titles:
    titles_list.append(tag.get_text())

titles_list
# Out:
# ['불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다',
#  '리버풀 선배의 분노와 조언 "유로파 8강 2차전 2군으로···PL 우승에 올인"',
#  '\'연습 때보다 경기때 더 잘하는 스타일\'  2군 타율 0. 417→첫 타석 데뷔 첫 3루타. 꽃감독 예상 적중. "칼을 갈고 있었다"',
#  "'0. 169 캡틴 살려라' 코치 총동원 야간 특타…'78억 첫해' 얼마나 답답했으면",
#  "'56홈런' 괴물타자에게 무슨일 있나…개막 10경기 45타석 무홈런-무타점",
#  '\'바이에른의 실패한 영입\' 김민재, 이제는 \'충격 스왑딜\' 가능성까지 등장…"세리에A 정상급 윙어와 바꿀 계획"']

# %%
list(map(lambda x: x.get_text(), titles))
# Out:
# ['불법 도박 통제 못한 오타니 통역사…1만9000회 베팅, 557억원 잃었다',
#  '리버풀 선배의 분노와 조언 "유로파 8강 2차전 2군으로···PL 우승에 올인"',
#  '\'연습 때보다 경기때 더 잘하는 스타일\'  2군 타율 0. 417→첫 타석 데뷔 첫 3루타. 꽃감독 예상 적중. "칼을 갈고 있었다"',
#  "'0. 169 캡틴 살려라' 코치 총동원 야간 특타…'78억 첫해' 얼마나 답답했으면",
#  "'56홈런' 괴물타자에게 무슨일 있나…개막 10경기 45타석 무홈런-무타점",
#  '\'바이에른의 실패한 영입\' 김민재, 이제는 \'충격 스왑딜\' 가능성까지 등장…"세리에A 정상급 윙어와 바꿀 계획"']
