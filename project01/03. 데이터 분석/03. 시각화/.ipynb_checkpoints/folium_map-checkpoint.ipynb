# %%
# !conda install -c conda-forge folium

# %%
import folium

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start =12)

# 지도를 HTML 파일로 저장하기
seoul_map.save('./seoul.html')

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63e76d42bfe4e6d676150b85976c01b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63e76d42bfe4e6d676150b85976c01b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63e76d42bfe4e6d676150b85976c01b6 = L.map(
#                 &quot;map_63e76d42bfe4e6d676150b85976c01b6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9772b2cc8db01565f820e9394f36a30e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9772b2cc8db01565f820e9394f36a30e.addTo(map_63e76d42bfe4e6d676150b85976c01b6);
#
#
#             tile_layer_9772b2cc8db01565f820e9394f36a30e.addTo(map_63e76d42bfe4e6d676150b85976c01b6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# from folium.map import Popup
# import pandas as pd
# import folium
df = pd.read_excel('./서울지역 대학교 위치.xlsx')
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
df.head()
# Out:
#             학교명         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abfe8aa79ba7d56bf7e4c8266e632c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abfe8aa79ba7d56bf7e4c8266e632c36 = L.map(
#                 &quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_093eff373d41788f8945426c0078bb1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_093eff373d41788f8945426c0078bb1b.addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#             var marker_cca84d581e1ab633af09c5bcd5eee72b = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_6a95d22dc3929a16e0aaffb18756a6ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8de8d0a5d4c70e759a751b6f63cf7ea = $(`&lt;div id=&quot;html_e8de8d0a5d4c70e759a751b6f63cf7ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_6a95d22dc3929a16e0aaffb18756a6ee.setContent(html_e8de8d0a5d4c70e759a751b6f63cf7ea);
#
#
#
#         marker_cca84d581e1ab633af09c5bcd5eee72b.bindPopup(popup_6a95d22dc3929a16e0aaffb18756a6ee)
#         ;
#
#
#
#
#             var marker_059325058f39f141e5d5cac90afed28e = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_7ce0912eeaf09b332685bf98da908f55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34c5411b2beb70d58f608edc8084eac1 = $(`&lt;div id=&quot;html_34c5411b2beb70d58f608edc8084eac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_7ce0912eeaf09b332685bf98da908f55.setContent(html_34c5411b2beb70d58f608edc8084eac1);
#
#
#
#         marker_059325058f39f141e5d5cac90afed28e.bindPopup(popup_7ce0912eeaf09b332685bf98da908f55)
#         ;
#
#
#
#
#             var marker_d0e2c8bf740675510b5e1a65cc985911 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_5cf915aacdb80066428ae38b96f6e1ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d92c3597d38cd7445860d418f4d0a927 = $(`&lt;div id=&quot;html_d92c3597d38cd7445860d418f4d0a927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_5cf915aacdb80066428ae38b96f6e1ae.setContent(html_d92c3597d38cd7445860d418f4d0a927);
#
#
#
#         marker_d0e2c8bf740675510b5e1a65cc985911.bindPopup(popup_5cf915aacdb80066428ae38b96f6e1ae)
#         ;
#
#
#
#
#             var marker_0b3049787d6989c14e9b4a043d7d9b0a = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_cb4cb23adc906a6225aa35acfe00d55c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d87c46af551a251939743a7a8e3c741 = $(`&lt;div id=&quot;html_8d87c46af551a251939743a7a8e3c741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_cb4cb23adc906a6225aa35acfe00d55c.setContent(html_8d87c46af551a251939743a7a8e3c741);
#
#
#
#         marker_0b3049787d6989c14e9b4a043d7d9b0a.bindPopup(popup_cb4cb23adc906a6225aa35acfe00d55c)
#         ;
#
#
#
#
#             var marker_3920574a625321e6e93f51dc7dee386c = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_c3eb9df7d9eac773e3c40edee77ca6c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a81f7685a7cf253edd9bdc1150dc3fd = $(`&lt;div id=&quot;html_5a81f7685a7cf253edd9bdc1150dc3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_c3eb9df7d9eac773e3c40edee77ca6c2.setContent(html_5a81f7685a7cf253edd9bdc1150dc3fd);
#
#
#
#         marker_3920574a625321e6e93f51dc7dee386c.bindPopup(popup_c3eb9df7d9eac773e3c40edee77ca6c2)
#         ;
#
#
#
#
#             var marker_f0396e75e5999f9932df97760d47bf02 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);

# %% [markdown]
# #### IFrame Popup

# %%
from folium.map import Popup
import pandas as pd
import folium
df = pd.read_excel('./서울지역 대학교 위치.xlsx')
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    iframe = folium.IFrame(name, width=300, height=80)
    popup = folium.Popup(iframe, max_width = 300)
    folium.Marker([lat, lng], popup=popup).add_to(seoul_map)
seoul_map.save('./seoul_colleges.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abfe8aa79ba7d56bf7e4c8266e632c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abfe8aa79ba7d56bf7e4c8266e632c36 = L.map(
#                 &quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_093eff373d41788f8945426c0078bb1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_093eff373d41788f8945426c0078bb1b.addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#             var marker_cca84d581e1ab633af09c5bcd5eee72b = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_6a95d22dc3929a16e0aaffb18756a6ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8de8d0a5d4c70e759a751b6f63cf7ea = $(`&lt;div id=&quot;html_e8de8d0a5d4c70e759a751b6f63cf7ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_6a95d22dc3929a16e0aaffb18756a6ee.setContent(html_e8de8d0a5d4c70e759a751b6f63cf7ea);
#
#
#
#         marker_cca84d581e1ab633af09c5bcd5eee72b.bindPopup(popup_6a95d22dc3929a16e0aaffb18756a6ee)
#         ;
#
#
#
#
#             var marker_059325058f39f141e5d5cac90afed28e = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_7ce0912eeaf09b332685bf98da908f55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34c5411b2beb70d58f608edc8084eac1 = $(`&lt;div id=&quot;html_34c5411b2beb70d58f608edc8084eac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_7ce0912eeaf09b332685bf98da908f55.setContent(html_34c5411b2beb70d58f608edc8084eac1);
#
#
#
#         marker_059325058f39f141e5d5cac90afed28e.bindPopup(popup_7ce0912eeaf09b332685bf98da908f55)
#         ;
#
#
#
#
#             var marker_d0e2c8bf740675510b5e1a65cc985911 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_5cf915aacdb80066428ae38b96f6e1ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d92c3597d38cd7445860d418f4d0a927 = $(`&lt;div id=&quot;html_d92c3597d38cd7445860d418f4d0a927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_5cf915aacdb80066428ae38b96f6e1ae.setContent(html_d92c3597d38cd7445860d418f4d0a927);
#
#
#
#         marker_d0e2c8bf740675510b5e1a65cc985911.bindPopup(popup_5cf915aacdb80066428ae38b96f6e1ae)
#         ;
#
#
#
#
#             var marker_0b3049787d6989c14e9b4a043d7d9b0a = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_cb4cb23adc906a6225aa35acfe00d55c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d87c46af551a251939743a7a8e3c741 = $(`&lt;div id=&quot;html_8d87c46af551a251939743a7a8e3c741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_cb4cb23adc906a6225aa35acfe00d55c.setContent(html_8d87c46af551a251939743a7a8e3c741);
#
#
#
#         marker_0b3049787d6989c14e9b4a043d7d9b0a.bindPopup(popup_cb4cb23adc906a6225aa35acfe00d55c)
#         ;
#
#
#
#
#             var marker_3920574a625321e6e93f51dc7dee386c = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_c3eb9df7d9eac773e3c40edee77ca6c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a81f7685a7cf253edd9bdc1150dc3fd = $(`&lt;div id=&quot;html_5a81f7685a7cf253edd9bdc1150dc3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_c3eb9df7d9eac773e3c40edee77ca6c2.setContent(html_5a81f7685a7cf253edd9bdc1150dc3fd);
#
#
#
#         marker_3920574a625321e6e93f51dc7dee386c.bindPopup(popup_c3eb9df7d9eac773e3c40edee77ca6c2)
#         ;
#
#
#
#
#             var marker_f0396e75e5999f9932df97760d47bf02 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);

# %% [markdown]
# #### 원형 popup

# %%
from folium.map import Popup
import pandas as pd
import folium
df = pd.read_excel('./서울지역 대학교 위치.xlsx')
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', zoom_start=12)

# %%
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                       radious=10,
                       color='brown',
                       fill=True,
                       fill_color='coral',
                       fill_opacity=0.7,
                       popup=name
    ).add_to(seoul_map)
seoul_map.save('./seoul_colleges2.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abfe8aa79ba7d56bf7e4c8266e632c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abfe8aa79ba7d56bf7e4c8266e632c36 = L.map(
#                 &quot;map_abfe8aa79ba7d56bf7e4c8266e632c36&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_093eff373d41788f8945426c0078bb1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_093eff373d41788f8945426c0078bb1b.addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#             var marker_cca84d581e1ab633af09c5bcd5eee72b = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_6a95d22dc3929a16e0aaffb18756a6ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8de8d0a5d4c70e759a751b6f63cf7ea = $(`&lt;div id=&quot;html_e8de8d0a5d4c70e759a751b6f63cf7ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_6a95d22dc3929a16e0aaffb18756a6ee.setContent(html_e8de8d0a5d4c70e759a751b6f63cf7ea);
#
#
#
#         marker_cca84d581e1ab633af09c5bcd5eee72b.bindPopup(popup_6a95d22dc3929a16e0aaffb18756a6ee)
#         ;
#
#
#
#
#             var marker_059325058f39f141e5d5cac90afed28e = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_7ce0912eeaf09b332685bf98da908f55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34c5411b2beb70d58f608edc8084eac1 = $(`&lt;div id=&quot;html_34c5411b2beb70d58f608edc8084eac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_7ce0912eeaf09b332685bf98da908f55.setContent(html_34c5411b2beb70d58f608edc8084eac1);
#
#
#
#         marker_059325058f39f141e5d5cac90afed28e.bindPopup(popup_7ce0912eeaf09b332685bf98da908f55)
#         ;
#
#
#
#
#             var marker_d0e2c8bf740675510b5e1a65cc985911 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_5cf915aacdb80066428ae38b96f6e1ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d92c3597d38cd7445860d418f4d0a927 = $(`&lt;div id=&quot;html_d92c3597d38cd7445860d418f4d0a927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_5cf915aacdb80066428ae38b96f6e1ae.setContent(html_d92c3597d38cd7445860d418f4d0a927);
#
#
#
#         marker_d0e2c8bf740675510b5e1a65cc985911.bindPopup(popup_5cf915aacdb80066428ae38b96f6e1ae)
#         ;
#
#
#
#
#             var marker_0b3049787d6989c14e9b4a043d7d9b0a = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_cb4cb23adc906a6225aa35acfe00d55c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d87c46af551a251939743a7a8e3c741 = $(`&lt;div id=&quot;html_8d87c46af551a251939743a7a8e3c741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_cb4cb23adc906a6225aa35acfe00d55c.setContent(html_8d87c46af551a251939743a7a8e3c741);
#
#
#
#         marker_0b3049787d6989c14e9b4a043d7d9b0a.bindPopup(popup_cb4cb23adc906a6225aa35acfe00d55c)
#         ;
#
#
#
#
#             var marker_3920574a625321e6e93f51dc7dee386c = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
#
#
#         var popup_c3eb9df7d9eac773e3c40edee77ca6c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a81f7685a7cf253edd9bdc1150dc3fd = $(`&lt;div id=&quot;html_5a81f7685a7cf253edd9bdc1150dc3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_c3eb9df7d9eac773e3c40edee77ca6c2.setContent(html_5a81f7685a7cf253edd9bdc1150dc3fd);
#
#
#
#         marker_3920574a625321e6e93f51dc7dee386c.bindPopup(popup_c3eb9df7d9eac773e3c40edee77ca6c2)
#         ;
#
#
#
#
#             var marker_f0396e75e5999f9932df97760d47bf02 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_abfe8aa79ba7d56bf7e4c8266e632c36);
