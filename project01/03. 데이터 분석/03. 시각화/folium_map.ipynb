# %%
# !conda install -c conda-forge folium

# %%
import folium

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start =12)

# 지도를 HTML 파일로 저장하기
seoul_map.save('./seoul.html')

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63e76d42bfe4e6d676150b85976c01b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63e76d42bfe4e6d676150b85976c01b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63e76d42bfe4e6d676150b85976c01b6 = L.map(
#                 &quot;map_63e76d42bfe4e6d676150b85976c01b6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9772b2cc8db01565f820e9394f36a30e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9772b2cc8db01565f820e9394f36a30e.addTo(map_63e76d42bfe4e6d676150b85976c01b6);
#
#
#             tile_layer_9772b2cc8db01565f820e9394f36a30e.addTo(map_63e76d42bfe4e6d676150b85976c01b6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.map import Popup
import pandas as pd
import folium
df = pd.read_excel('./서울지역 대학교 위치.xlsx')
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45d66476ee1165d5ce468209ab2b2f80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45d66476ee1165d5ce468209ab2b2f80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45d66476ee1165d5ce468209ab2b2f80 = L.map(
#                 &quot;map_45d66476ee1165d5ce468209ab2b2f80&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3294b04c0fc238be7d94e5c80ef0f95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e3294b04c0fc238be7d94e5c80ef0f95.addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#             var marker_dcac477e362e65dc2e6af934d9d9daa1 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_76f33e033f22a1cc0162100128bcecdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a2c723d11cee140fb37269803ac2d60 = $(`&lt;div id=&quot;html_0a2c723d11cee140fb37269803ac2d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_76f33e033f22a1cc0162100128bcecdb.setContent(html_0a2c723d11cee140fb37269803ac2d60);
#
#
#
#         marker_dcac477e362e65dc2e6af934d9d9daa1.bindPopup(popup_76f33e033f22a1cc0162100128bcecdb)
#         ;
#
#
#
#
#             var marker_9a74583380a09c256054bb92fd504dea = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_9057ea8228afed896bc2960803ba51b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2b86fb59536102e0548459903795894 = $(`&lt;div id=&quot;html_b2b86fb59536102e0548459903795894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_9057ea8228afed896bc2960803ba51b1.setContent(html_b2b86fb59536102e0548459903795894);
#
#
#
#         marker_9a74583380a09c256054bb92fd504dea.bindPopup(popup_9057ea8228afed896bc2960803ba51b1)
#         ;
#
#
#
#
#             var marker_53849a80aeca0decaecec7eed5a2644b = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_ae1daf9782a9f181eb96d02e4d76abb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ce31a35e2168f11417f8f822393cf36 = $(`&lt;div id=&quot;html_7ce31a35e2168f11417f8f822393cf36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_ae1daf9782a9f181eb96d02e4d76abb7.setContent(html_7ce31a35e2168f11417f8f822393cf36);
#
#
#
#         marker_53849a80aeca0decaecec7eed5a2644b.bindPopup(popup_ae1daf9782a9f181eb96d02e4d76abb7)
#         ;
#
#
#
#
#             var marker_a6fb99c58a874b1f79c03d1b521380dd = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_d4ffcc0ae1d13dffba979fb7dc144a28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_606abbba77d0f6de8d3bbc09955e7f51 = $(`&lt;div id=&quot;html_606abbba77d0f6de8d3bbc09955e7f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_d4ffcc0ae1d13dffba979fb7dc144a28.setContent(html_606abbba77d0f6de8d3bbc09955e7f51);
#
#
#
#         marker_a6fb99c58a874b1f79c03d1b521380dd.bindPopup(popup_d4ffcc0ae1d13dffba979fb7dc144a28)
#         ;
#
#
#
#
#             var marker_3853ced82fa075508a9cbac085439e56 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_1d964783c92ea9e54c10daad97bebfe7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e19638c16dd89388913d9d1de8bb0fa = $(`&lt;div id=&quot;html_0e19638c16dd89388913d9d1de8bb0fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_1d964783c92ea9e54c10daad97bebfe7.setContent(html_0e19638c16dd89388913d9d1de8bb0fa);
#
#
#
#         marker_3853ced82fa075508a9cbac085439e56.bindPopup(popup_1d964783c92ea9e54c10daad97bebfe7)
#         ;
#
#
#
#
#             var marker_ee7a826e497bcae42e2132e67ad24567 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_45d66476ee1165d5ce468209ab2b2f80);
#
#
#         var popup_1722d5f4b4da06bd3b2f49e3ac5
