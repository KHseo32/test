# %% [markdown]
# ## Request

# %%
# 네이버 연결 확인

import requests

res = requests.get("http://naver.com")
print("status_code : ", res.status_code)  # 정상 : 200
# Out:
# status_code :  200

# %%
# 연결 에러 처리
res = requests.get("http://yyy.tistory.com")
if res.status_code == requests.codes.ok:
    print("정상")
else:
    print("오류 : ", res.status_code)
# Out:
# 오류 :  404

# %%
import requests

res = requests.get("http://naver.com")
# res = requests.get("http://yyy.tistory.com")
res.raise_for_status()  # 오류일 경우 시스템 종료, 정상일 경우는 다음 step으로 진행

print("정상입니다.")
print(len(res.text))
print(res.text)
# Out:
# 정상입니다.
# 202875
# ...

# %% [markdown]
# ## Urllib

# %%
# urlopen
from urllib.request import urlopen

url = "https://www.naver.com"
html = urlopen(url)
print(html.read())
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...

# %%
# errorHttp
from urllib.request import urlopen
from urllib.request import HTTPError

try:
    html = urlopen("http://www.google.com/kim.html")
except HTTPError as e:
    print(e)
else:
    print("성공")
# Out:
# HTTP Error 404: Not Found

# %%
# errorURL
from urllib.request import urlopen
from urllib.request import HTTPError
from urllib.request import URLError

try:
    html = urlopen("http://www.dddsdf.com/kim.html")
except HTTPError as e:
    print(e)
except URLError as e:
    print('The server coult not be found!')
else:
    print("성공")

# %% [markdown]
# ## Beautifulsoup
# * scraping(parsing 후 데이터 추출)

# %%
import bs4 

html_str = "<html><div>hello</div></html>"
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")

print(type(html_str))
print(type(bs_obj))
print(bs_obj) 
print(bs_obj.find("div"))
# Out:
# <class 'str'>
# <class 'bs4.BeautifulSoup'>
# <html><div>hello</div></html>
# <div>hello</div>

# %%
import bs4 

html_str = """
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")
ul = bs_obj.find("ul")
print(ul)
# Out:
# <ul>
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
li = ul.find("li")
print(li)
print(li.text)
# Out:
# <li>hello</li>
# hello

# %%
lis = ul.findAll("li")
print(type(lis))
print(lis)
print(lis[1])
print(lis[1].text)
# Out:
# <class 'bs4.element.ResultSet'>
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]
# <li>bye</li>
# bye

# %%
import bs4 

html_str = """
<html>
    <body>
        <ul class = "greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
        <ul class = "reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")
ul = bs_obj.find("ul")
print(ul)
# Out:
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
# class로 데이터 찾기
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")
ul = bs_obj.find("ul", {"class":"reply"})
print(ul)
# Out:
# <ul class="reply">
# <li>ok</li>
# <li>no</li>
# <li>sure</li>
# </ul>

# %%
import bs4 

html_str = """
<html>
    <body>
        <ul class = "ko">
            <li>
                <a href = "http://www.naver.com/">네이버</a>
            </li>
            <li>
                <a href = "http://www.daum.com/">다음</a>
            </li>
        </ul>
        <ul class = "sns">
            <li>
                <a href = "http://www.google.com/">구글</a>
            </li>
            <li>
                <a href = "http://www.facebook.com/">페이스북</a>
            </li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")
atag = bs_obj.find("a")
print(atag)
print(atag.text)
print(atag['href'])
# Out:
# <a href="http://www.naver.com/">네이버</a>
# 네이버
# http://www.naver.com/

# %%
# http://www.google.com/, 구글 추출
# 방법1
sns = bs_obj.find("ul", {"class":"sns"})
sns_li = sns.find("li")
sns_li_a = sns_li.find("a")

print(sns)
print("="* 30)
print(sns_li)
print("="* 30)
print(sns_li_a)
print(sns_li_a["href"], sns_li_a.text)
# Out:
# <ul class="sns">
# <li>
# <a href="http://www.google.com/">구글</a>
# </li>
# <li>
# <a href="http://www.facebook.com/">페이스북</a>
# </li>
# </ul>
# ...
# <li>
# <a href="http://www.google.com/">구글</a>
# </li>
# ...
# <a href="http://www.google.com/">구글</a>
# http://www.google.com/ 구글

# %%
# 방법2
sns = bs_obj.find("ul", {"class":"sns"})
sns_li = sns.findAll("li")[0]
print(sns_li.find("a")["href"])
print(sns_li.find("a").text)
# Out:
# http://www.google.com/
# 구글

# %%
# 방법3
sns = bs_obj.find("ul", {"class":"sns"})
sns_li = sns.findAll("a")
print(sns_li)
print(sns_li[0])
# Out:
# [<a href="http://www.google.com/">구글</a>, <a href="http://www.facebook.com/">페이스북</a>]
# <a href="http://www.google.com/">구글</a>

# %% [markdown]
# ## 응용 : 다음 영화 역대관객순위 Top5 image

# %%
import requests
from bs4 import BeautifulSoup

# Crawling
url = "https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=2023%EB%85%84%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84"
res = requests.get(url)
res.raise_for_status()

# Scraping
soup = BeautifulSoup(res.text, "html.parser")
movie = soup.find("ul", {"class":"c-list-basic"})
movies = movie.find("div", {"class":"c-paging"})
movies
# movie_lis= movie.findAll("li")



# for idx, movie in enumerate(movie_lis):
#     print(idx, movie)

# %% [markdown]
# ## Selenium

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

service = Service()  # Selenium 서비스 생성
options = webdriver.ChromeOptions()  # Chrome 브라우저의 옵션을 설정
driver = webdriver.Chrome(service=service, options=options) # Chrome 브라우저 실행

sec = 2
url = "http://naver.com"

# driver는 Chrome을 제어할 수 있는 selenium임
driver.get(url)
time.sleep(sec)
driver.back()
time.sleep(sec)
driver.forward()
time.sleep(sec)
driver.refresh()
time.sleep(sec)
driver.back()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 

from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

url = "http://naver.com"
driver.get(url)

element = driver.find_element(By.ID, "query")
element.send_keys("컴퓨터")
element.send_keys(Keys.ENTER)

# %%
url = "http://naver.com"
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

try:
    #네이버 이동
    driver.get(url)
    # 로그인 버튼 클릭
    element = driver.find_element(By.CLASS_NAME, "MyView-module__link_login___HpHMW")
    element.click()
    
    # id, pass 입력
    driver.find_element(By.ID, "id").send_keys("본인 ID")
    driver.find_element(By.ID, "pw").send_keys("본인 Password")
    
    driver.find_element(By.ID, "log.login").click()
    print(driver.page_source)
except Exception as e:
    print(e)

# %%
# naver 로긴(우회해서 접속)
import pyperclip
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
url = "http://naver.com"
driver.get(url)
try:
    #네이버 이동
    driver.get(url)
    # 로그인 버튼 클릭
    element = driver.find_element(By.CLASS_NAME, "MyView-module__link_login___HpHMW")
    element.click()
    # id, pass 입력
    pyperclip.copy("아이디")
    driver.find_element(By.ID, "id").send_keys(Keys.CONTROL, 'v')
    pyperclip.copy("비밀번호")
    driver.find_element(By.ID, "pw").send_keys(Keys.CONTROL, 'v')
    driver.find_element(By.ID, "log.login").click()
    print(driver.page_source)
except Exception as e:
    print(e)

# %%
# !pip install webdriver_manager

# %%
## project(쿠팡 데이터 수집)
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import requests
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
service=Service()
options=webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://www.coupang.com/np/categories/194276')

# %%
productlist = driver.find_element(By.ID, 'productList')
lis=productlist.find_elements(By.TAG_NAME, 'li')

prd_name=[]
prd_price=[]
prd_deli=[]
prd_url =[]

for idx, li in enumerate(lis):
    try:
        prd_name.append(li.find_element(By.CLASS_NAME, 'name').text)
        prd_price.append(li.find_element(By.CLASS_NAME, 'price-value').text)
        prd_deli.append(li.find_element(By.CLASS_NAME, 'delivery').text)
        prd_url.append(li.find_element(By.CLASS_NAME, 'baby-product-link').get_attribute('href'))

        e = li.find_element(By.TAG_NAME, 'img')
        img_url = e.get_attribute('src')
        img_res = requests.get(img_url)
        img_res.raise_for_status()

        food_name = "./image/food{}.jpg".format(idx+1)
        with open(food_name, 'wb') as f:
            f.write(img_res.content)

        if idx >=5:
            break
    except Exception:
        pass



print(prd_deli)
print(prd_name)
print(prd_price)
print(prd_url)
# import pandas as pd

# # 데이터 프레임 생성
# df = pd.DataFrame({
#     'Product Name': prd_name,
#     'Price': prd_price,
#     'Delivery Details': prd_deli,
#     # 'Product URL': prd_url
# })

# # CSV 파일로 저장
# csv_filename = 'coupang_products.csv'
# df.to_csv(csv_filename, index=False)

# print(f"제품 정보가 '{csv_filename}' 파일로 성공적으로 추출되었습니다.")
# Out:
# ['내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '4/20(토) 도착 예정', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 예정', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 예정', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 새벽 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장', '내일(목) 도착 보장']
# ...
